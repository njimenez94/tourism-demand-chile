# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "../src")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data.FuncionesTarea import process, build_series

# %%
# !ls ../data/raw
# Out:
# 202512-llegadas-de-turistas-extranjeros.xlsx

# %%
RAW_FILE = '../data/raw/202512-llegadas-de-turistas-extranjeros.xlsx'

df = process(RAW_FILE)
# Out:
#       period           region    country crossing_type  \
# 0 2013-01-01           Europa   Alemania   Aeropuertos
# 1 2013-01-01  America Del Sur  Argentina   Aeropuertos
# 2 2013-01-01          Oceania  Australia   Aeropuertos
# 3 2013-01-01           Europa    Austria   Aeropuertos
# 4 2013-01-01           Europa    Belgica   Aeropuertos
#
#            crossing_detail  arrivals
# 0  Chacalluta - Aeropuerto        41
# 1  Chacalluta - Aeropuerto       264
# 2  Chacalluta - Aeropuerto        77
# 3  Chacalluta - Aeropuerto         3
# 4  Chacalluta - Aeropuerto         3

# %% [markdown]
# # Explora

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 186777 entries, 0 to 186776
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   period           186777 non-null  datetime64[us]
#  1   region           186777 non-null  str
#  2   country          186777 non-null  str
#  3   crossing_type    186777 non-null  str
#  4   crossing_detail  186777 non-null  str
#  5   arrivals         186777 non-null  int64
# dtypes: datetime64[us](1), int64(1), str(4)
# memory usage: 8.6 MB

# %%
df.head()
# Out:
#       period           region    country crossing_type  \
# 0 2013-01-01           Europa   Alemania   Aeropuertos
# 1 2013-01-01  America Del Sur  Argentina   Aeropuertos
# 2 2013-01-01          Oceania  Australia   Aeropuertos
# 3 2013-01-01           Europa    Austria   Aeropuertos
# 4 2013-01-01           Europa    Belgica   Aeropuertos
#
#            crossing_detail  arrivals
# 0  Chacalluta - Aeropuerto        41
# 1  Chacalluta - Aeropuerto       264
# 2  Chacalluta - Aeropuerto        77
# 3  Chacalluta - Aeropuerto         3
# 4  Chacalluta - Aeropuerto         3

# %% [markdown]
# # Series de tiempo

# %%
ts_arg = build_series(df, country="Argentina")
